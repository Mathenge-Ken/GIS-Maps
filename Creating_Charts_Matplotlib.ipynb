# %% [markdown]
# <a href="https://colab.research.google.com/github/Mathenge-Ken/GIS-Maps/blob/main/Creating_Charts_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Overview
#
# Pandas allows you to read structured datasets and visualize them using the `plot()` method. By default, Pandas uses `matplotlib` to create the plots.
#
# In this notebook, we will take work with open dataset of crime in London.

# %% [markdown]
# ## Setup and Data Download
#
# The following blocks of code will install the required packages and download the datasets to your Colab environment.

# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
import requests

# %%
data_folder = 'data'
output_folder = 'output'

if not os.path.exists(data_folder):
    os.mkdir(data_folder)
if not os.path.exists(output_folder):
    os.mkdir(output_folder)

# %%
def download(url):
    filename = os.path.join(data_folder, os.path.basename(url))
    if not os.path.exists(filename):
      with requests.get(url, stream=True, allow_redirects=True) as r:
          with open(filename, 'wb') as f:
              for chunk in r.iter_content(chunk_size=8192):
                  f.write(chunk)
      print('Downloaded', filename)

# %% [markdown]
# We have 12 different CSV files containing crime data for each month of 2020. We download each of them to the data folder.

# %%
files = [
  '2020-01-metropolitan-street.csv',
  '2020-02-metropolitan-street.csv',
  '2020-03-metropolitan-street.csv',
  '2020-04-metropolitan-street.csv',
  '2020-05-metropolitan-street.csv',
  '2020-06-metropolitan-street.csv',
  '2020-07-metropolitan-street.csv',
  '2020-08-metropolitan-street.csv',
  '2020-09-metropolitan-street.csv',
  '2020-10-metropolitan-street.csv',
  '2020-11-metropolitan-street.csv',
  '2020-12-metropolitan-street.csv'
]


data_url = 'https://github.com/spatialthoughts/python-dataviz-web/releases/' \
  'download/police.uk/'

for f in files:
  url = os.path.join(data_url + f)
  download(url)
# Out:
# Downloaded data/2020-01-metropolitan-street.csv
# Downloaded data/2020-02-metropolitan-street.csv
# Downloaded data/2020-03-metropolitan-street.csv
# Downloaded data/2020-04-metropolitan-street.csv
# Downloaded data/2020-05-metropolitan-street.csv
# Downloaded data/2020-06-metropolitan-street.csv
# Downloaded data/2020-07-metropolitan-street.csv
# Downloaded data/2020-08-metropolitan-street.csv
# Downloaded data/2020-09-metropolitan-street.csv
# Downloaded data/2020-10-metropolitan-street.csv
# Downloaded data/2020-11-metropolitan-street.csv
# Downloaded data/2020-12-metropolitan-street.csv

# %% [markdown]
# It will be helpful to merge all 12 CSV files into a single dataframe. We can use `pd.concat()` to merge a list of dataframes.

# %%
dataframe_list = []

for f in files:
    filepath = os.path.join(data_folder, f)
    df = pd.read_csv(filepath)
    dataframe_list.append(df)

merged_df = pd.concat(dataframe_list)

# %% [markdown]
# The resulting dataframe consists of over 1 million records of various crimes recorded in London in the year 2020.

# %%
merged_df
# Out:
#                                                 Crime ID    Month  \
# 0      24c2b43c34c7cd6ef847d69fbb042c9c730b1eebe95c52...  2020-01
# 1                                                    NaN  2020-01
# 2                                                    NaN  2020-01
# 3                                                    NaN  2020-01
# 4                                                    NaN  2020-01
# ...                                                  ...      ...
# 87931  05780af1c8515c41499ef396a33fc4e5c248533cecd9c4...  2020-12
# 87932  54ce60d717f01752c5ff44f870e07a503e3fbeaae0b91e...  2020-12
# 87933  580fdc2edfe26a09392ab6b9128732ba0c7cd05695387a...  2020-12
# 87934  2730906a962972bed3589463c9be9dbb8ee8e594b779a3...  2020-12
# 87935  826ceb8d3d2f79363e852449055994f5a8fec53b938fd7...  2020-12
#
#                        Reported by                 Falls within  Longitude  \
# 0      Metropolitan Police Service  Metropolitan Police Service  -0.539301
# 1      Metropolitan Police Service  Metropolitan Police Service   0.134947
# 2      Metropolitan Police Service  Metropolitan Police Service   0.140035
# 3      Metropolitan Police Service  Metropolitan Police Service   0.137065
# 4      Metropolitan Police Service  Metropolitan Police Service   0.137065
# ...                            ...                          ...        ...
# 87931  Metropolitan Police Service  Metropolitan Police Service        NaN
# 87932  Metropolitan Police Service  Metropolitan Police Service        NaN
# 87933  Metropolitan Police Service  Metropolitan Police Service        NaN
# 87934  Metropolitan Police Service  Metropolitan Police Service        NaN
# 87935  Metropolitan Police Service  Metropolitan Police Service        NaN
#
#         Latitude                    Location  LSOA code  \
# 0      50.817200   On or near Highdown Drive  E01031469
# 1      51.588063       On or near Mead Grove  E01000027
# 2      51.589112  On or near Beansland Grove  E01000027
# 3      51.583672   On or near Police Station  E01000027
# 4      51.583672   On or near Police Station  E01000027
# ...          ...                         ...        ...
# 87931        NaN                 No Location        NaN
# 87932        NaN                 No Location        NaN
# 87933        NaN                 No Location        NaN
# 87934        NaN                 No Location        NaN
# 87935        NaN                 No Location        NaN
#
#                        LSOA name                    Crime type  \
# 0                      Arun 009F                   Other theft
# 1      Barking and Dagenham 001A         Anti-social behaviour
# 2      Barking and Dagenham 001A         Anti-social behaviour
# 3      Barking and Dagenham 001A         Anti-social behaviour
# 4      Barking and Dagenham 001A         Anti-social behaviour
# ...                          ...                           ...
# 87931                        NaN  Violence and sexual offences
# 87932                        NaN                   Other crime
# 87933                        NaN                   Other crime
# 87934                        NaN                   Other crime
# 87935                        NaN                   Other crime
#
#                                Last outcome category  Context
# 0                          Status update unavailable      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NaN
# 3                                                NaN      NaN
# 4                                                NaN      NaN
# ...                                              ...      ...
# 87931  Investigation complete; no suspect identified      NaN
# 87932  Investigation complete; no suspect identified      NaN
# 87933                       Offender given a caution      NaN
# 87934  Investigation complete; no suspect identified      NaN
# 87935                      Status update unavailable      NaN
#
# [1181922 rows x 12 columns]

# %% [markdown]
# ## Create a Pie-Chart

# %%
merged_df.shape
# Out:
# (1181922, 12)

# %% [markdown]
# Let's create a pie-chart showing the distribution of different types of crime. Pandas `groupby()` function allows us to calculate group statistics.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming merged_df is your DataFrame
type_counts = merged_df.groupby('Crime type').size()

# Sort the counts from large to small
sorted_type_counts = type_counts.sort_values(ascending=False)

# Create a bar plot for visualization
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15, 10)
sorted_type_counts.plot(kind='pie', ax=ax)
plt.title('Crime Type Counts')
plt.xlabel('Crime Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
type_counts = merged_df.groupby('Crime type').size()
type_counts
# Out:
# Crime type
# Anti-social behaviour           415105
# Bicycle theft                    23517
# Burglary                         61044
# Criminal damage and arson        50923
# Drugs                            51629
# Other crime                      10066
# Other theft                      81924
# Possession of weapons             5763
# Public order                     53458
# Robbery                          27269
# Shoplifting                      34588
# Theft from the person            31084
# Vehicle crime                   108344
# Violence and sexual offences    227208
# dtype: int64

# %% [markdown]
# We now uses the `plot()` method to create the chart. This method is a wrapper around `matplotlib` and can accept supported arguments from it.
#
# Reference: [`pandas.DataFrame.plot`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15,10)
type_counts.plot(kind='pie', ax=ax)
plt.show()

# %% [markdown]
# Let's customize the chart. First we use `set_title()` method to add a title to the chart and `set_ylabel()` to remove the empty y-axis label. Lastly, we use the `plt.tight_layout()` to remove the extra whitespace around the plot.

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15,10)

type_counts.plot(kind='pie', ax=ax)

ax.set_title('Crime Types', fontsize = 18)
ax.set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# Matplotlib plots offer unlimited possibilities to customize your charts. Let's see some of the options available to customize the pie-chart.
#
# * `wedgeprops`: Customize the look of each 'wedge' of the pie.
# * `textprops`: Set the text properties of labels.
#
# Reference: [`matplotlib.pyplot.pie`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html)

# %%
wedgeprops={'linewidth': 3, 'edgecolor': 'white'}
textprops= {'fontsize': 10, 'fontstyle': 'italic'}

fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15,10)

type_counts.plot(kind='pie', ax=ax,
                 wedgeprops=wedgeprops,
                 textprops=textprops
                 )

ax.set_title('Crime Types', fontsize = 18)
ax.set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Create a Bar Chart
#
# We can also chart the trend of crime over the year. For this, let's group the data by month.

# %%
monthly_counts = merged_df.groupby('Month').size()
monthly_counts
# Out:
# Month
# 2020-01     90979
# 2020-02     86984
# 2020-03     87409
# 2020-04    109951
# 2020-05    114008
# 2020-06    100198
# 2020-07    103657
# 2020-08    104782
# 2020-09     99633
# 2020-10     99471
# 2020-11     96914
# 2020-12     87936
# dtype: int64

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15,7)
monthly_counts.plot(kind='bar', ax=ax)
plt.show()

# %% [markdown]
# As we learnt earlier, we can add multiple plots on the same Axes. We can add a `line` chart along with the `bar` chart to show the trendline as well. Lastly we add the titles and axis labels to finish the chart.

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15,7)

monthly_counts.plot(kind='bar', ax=ax)
monthly_counts.plot(kind='line', ax=ax, color='red', marker='o')

ax.set_title('Total Crime by Month')
ax.set_ylabel('Total Incidents')

plt.show()

# %% [markdown]
# ## Exercise
#
# Plot the trend of Bicycle thefts as a line chart.
#
# <img src='https://courses.spatialthoughts.com/images/python_dataviz/bicycle_thefts.png' width=800/>

# %% [markdown]
#  The cell below filters the `merged_df` dataframe to select incidents of 'Bicycle theft'. Group the results by months and plot the results.

# %%
bicycle_thefts = merged_df[merged_df['Crime type'] == 'Bicycle theft']

# %%
type(bicycle_thefts)
# Out:
# pandas.core.frame.DataFrame

# %%
bicycle_thefts.head()
# Out:
#                                                Crime ID    Month  \
# 360   c094393925bb094348a2d13933aaa0d0b38c12a09c0e7c...  2020-01
# 619   6984333ffb944f2fd3b5045bccfe35ed2796799e57cbce...  2020-01
# 1075  f2d8f21dc493c1167f32e34b143a8291cb4a18342fe037...  2020-01
# 1076  e0b29f9c97d5916a1e36a2873147bdd1cbfdfa0264a95e...  2020-01
# 1077  d3967d5b1463721962ca92c89462e165343cf06385acf5...  2020-01
#
#                       Reported by                 Falls within  Longitude  \
# 360   Metropolitan Police Service  Metropolitan Police Service   0.153621
# 619   Metropolitan Police Service  Metropolitan Police Service   0.165546
# 1075  Metropolitan Police Service  Metropolitan Police Service   0.076951
# 1076  Metropolitan Police Service  Metropolitan Police Service   0.080059
# 1077  Metropolitan Police Service  Metropolitan Police Service   0.077044
#
#        Latitude                    Location  LSOA code  \
# 360   51.552200  On or near Sedgemoor Drive  E01000064
# 619   51.545110   On or near Police Station  E01000036
# 1075  51.536326      On or near East Street  E01000010
# 1076  51.537440   On or near Police Station  E01000010
# 1077  51.537106     On or near Parking Area  E01000010
#
#                       LSOA name     Crime type  \
# 360   Barking and Dagenham 006E  Bicycle theft
# 619   Barking and Dagenham 010B  Bicycle theft
# 1075  Barking and Dagenham 015C  Bicycle theft
# 1076  Barking and Dagenham 015C  Bicycle theft
# 1077  Barking and Dagenham 015C  Bicycle theft
#
#                               Last outcome category  Context
# 360   Investigation complete; no suspect identified      NaN
# 619                       Status update unavailable      NaN
# 1075  Investigation complete; no suspect identified      NaN
# 1076                      Status update unavailable      NaN
# 1077                      Status update unavailable      NaN

# %%
bicycle_thefts = merged_df[merged_df['Crime type'] == 'Bicycle theft']

# Group by Month and count incidents
# bicycle_thefts['Month'] = pd.to_datetime(bicycle_thefts['Month'], format='%Y-%m')  # Ensure 'Month' is in datetime format
monthly_counts = bicycle_thefts.groupby(bicycle_thefts['Month']).size()

# %%
monthly_counts
# Out:
# Month
# 2020-01    1172
# 2020-02    1044
# 2020-03    1078
# 2020-04    1060
# 2020-05    1768
# 2020-06    2548
# 2020-07    2833
# 2020-08    3019
# 2020-09    3078
# 2020-10    2619
# 2020-11    1985
# 2020-12    1313
# dtype: int64

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15, 10)
monthly_counts.plot(kind="line", ax=ax, color="red")
plt.show()
